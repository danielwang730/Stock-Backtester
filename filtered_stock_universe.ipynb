# %%
# filter 7606 firstrate stocks and the the days meeting criteria: all based upon daily candles
# criteria
# $10 or above on all prices on a given day
# ATR $0.50 14 day moving average
# avg volume on a day of 500000 shares or above 
# ?if can do market cap on the day of 50M or above (?Finviz)
# will move parquet files of the stock universe and restrict to days that fulfill criteria 
# then use this universe and days for Stock in Play universe

# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime as dt
import shutil
import sys
import traceback

import requests


API_key = os.getenv("Polygon_IO_API_Key")

# %%
source_folder = "G:/My Drive/Backtesting/FirstRateData/Stocks/filtered/stocks1day-csv-analyzed/"
stats_folder ="G:/My Drive/Backtesting/FirstRateData/Stocks/filtered/"
destination_folder = "G:/My Drive/Backtesting/FirstRateData/Stocks/filtered/filtered-1day-csv/"

#sample_ticker = "PLTR"
vol_threshold = 500000
atr_threshold = 0.5
price_threshold = 10
market_cap_threshold = 50000000

# %%
# this cell code takes in 1min csv data and writes a new file with ATR, price and volume conditions in new columns 

start = dt.now()
num_zero_days_counter = 0 
num_error_counter = 0
num_zero_days_tickers = []
num_error_tickers = []

for filename in os.listdir(source_folder):

    try:
        filename_str = str(filename)
        ticker = filename_str.split('_')[0]
        #print(ticker)

        df = pd.read_csv(source_folder + '/' + filename_str)
        df['Datetime'] = pd.to_datetime(df['Datetime'])
        df.set_index('Datetime', inplace=True)

        # volume threshold
        pd.options.display.float_format = '{:.2f}'.format
        df['Volume_14d'] = df['Volume'].rolling(window=14).mean().fillna(0).astype(int)

        df['vol_condition'] = df['Volume_14d'] >= vol_threshold

        df['range'] = df['High'] - df['Low']
        df['ATR_14d'] = df['range'].rolling(window=14).mean().fillna(0)
        df['atr_condition'] = df['ATR_14d'] >= atr_threshold

        df['price_condition'] = (df['Open'] >= price_threshold) & (df['High'] >= price_threshold) & (df['Low'] >= price_threshold) & (df['Close'] >= price_threshold)
        df['all_conditions'] = df['vol_condition'] & df['atr_condition'] & df['price_condition']

        num_zero_days = len(df[df['all_conditions'] == True])

        if num_zero_days == 0:
            num_zero_days_counter += 1
            print("no days meet criteria: ", ticker)
            num_zero_days_tickers.append(ticker)

        df.to_csv(destination_folder + ticker + "_full_1day_UNADJUSTED" + "_filtered.csv")
    except Exception as e:
        print(e)
        print("error with " + ticker)
        num_error_counter += 1
        num_error_tickers.append(ticker)
        continue
num_zero_days_tickers_df = pd.DataFrame(num_zero_days_tickers)
num_error_tickers_df = pd.DataFrame(num_error_tickers)
num_zero_days_tickers_df.to_csv(stats_folder + "num_zero_days_tickers.csv")
num_error_tickers_df.to_csv(stats_folder + "num_error_tickers.csv")
end = dt.now()
print(start)
print(end)
print(end-start)
print("num_zero_days_counter: ", num_zero_days_counter)
# Out:
# no days meet criteria:  AHT.G
# no days meet criteria:  ANG.A
# no days meet criteria:  AMCR
# no days meet criteria:  ANEB
# no days meet criteria:  ALX
# no days meet criteria:  ALL.H
# no days meet criteria:  ALCY
# no days meet criteria:  ALG
# no days meet criteria:  ABSI
# no days meet criteria:  AMH.H
# no days meet criteria:  ANSCU
# no days meet criteria:  AHG
# no days meet criteria:  AHT.F
# no days meet criteria:  AGRIW
# no days meet criteria:  AMPGW
# no days meet criteria:  ALOT
# no days meet criteria:  ALRS
# no days meet criteria:  ANSC
# no days meet criteria:  ALL.B
# no days meet criteria:  ALSAR
# no days meet criteria:  ANSCW
# no days meet criteria:  AMH.G
# no days meet criteria:  AKYA
# no days meet criteria:  ALRN
# no days meet criteria:  AMPY
# no days meet criteria:  ALSAU
# no days meet criteria:  ALMS
# no days meet criteria:  ALTI
# no days meet criteria:  ALTM
# no days meet criteria:  AKTX
# no days meet criteria:  ANL
# no days meet criteria:  AE
# no days meet criteria:  AHL.C
# no days meet criteria:  ACNB
# no days meet criteria:  AFJKR
# no days meet criteria:  AFRIW
# no days meet criteria:  AGNCN
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 38
#      35         print("no days meet criteria: ", ticker)
#      36         num_zero_days_tickers.append(ticker)
# ---> 38     df.to_csv(destination_folder + ticker + "_full_1day_UNADJUSTED" + "_filtered.csv")
#      39 except Exception as e:
#      40     print(e)
#
# File c:\USERS\DANSK\ONEDRIVE\DOCUMENTS\GITHUB\BACKTESTER\STOCK_BACKTESTER\.STOCK_BACKTEST1_ENV\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\USERS\DANSK\ONEDRIVE\DOCUMENTS\GITHUB\BACKTESTER\STOCK_BACKTESTER\.STOCK_BACKTEST1_ENV\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\USERS\DANSK\ONEDRIVE\DOCUMENTS\GITHUB\BACKTESTER\STOCK_BACKTESTER\.STOCK_BACKTEST1_ENV\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\USERS\DANSK\ONEDRIVE\DOCUMENTS\GITHUB\BACKTESTER\STOCK_BACKTESTER\.STOCK_BACKTEST1_ENV\Lib\site-packages\pandas\io\formats\csvs.py:270, in CSVFormatter.save(self)
#     251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#    (...)
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
# --> 270     self._save()
#
# File c:\USERS\DANSK\ONEDRIVE\DOCUMENTS\GITHUB\BACKTESTER\STOCK_BACKTESTER\.STOCK_BACKTEST1_ENV\Lib\site-packages\pandas\io\formats\csvs.py:275, in CSVFormatter._save(self)
#     273 if self._need_to_save_header:
#     274     self._save_header()
# --> 275 self._save_body()
#
# File c:\USERS\DANSK\ONEDRIVE\DOCUMENTS\GITHUB\BACKTESTER\STOCK_BACKTESTER\.STOCK_BACKTEST1_ENV\Lib\site-packages\pandas\io\formats\csvs.py:313, in CSVFormatter._save_body(self)
#     311 if start_i >= end_i:
#     312     break
# --> 313 self._save_chunk(start_i, end_i)
#
# File c:\USERS\DANSK\ONEDRIVE\DOCUMENTS\GITHUB\BACKTESTER\STOCK_BACKTESTER\.STOCK_BACKTEST1_ENV\Lib\site-packages\pandas\io\formats\csvs.py:324, in CSVFormatter._save_chunk(self, start_i, end_i)
#     321 data = list(res._iter_column_arrays())
#     323 ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
# --> 324 libwriters.write_csv_rows(
#     325     data,
#     326     ix,
#     327     self.nlevels,
#     328     self.cols,
#     329     self.writer,
#     330 )
#
# File writers.pyx:56, in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:

# %%
num_error_counter
# Out:
# 1

# %%
# this code filters the tickers based upon tickers, days that fulfill criteria and adds market cap threshold
# it write parquet files for the filtered tickers and days

start = dt.now()
source_filtered_csv_folder = "G:/My Drive/Backtesting/FirstRateData/Stocks/filtered/filtered-1day-csv/"
# test folder with one file 
#source_filtered_csv_folder = "G:/My Drive/Backtesting/FirstRateData/Stocks/filtered/test-filtered-1day-csv/"

destination_parquet_folder = "G:/My Drive/Backtesting/FirstRateData/Stocks/filtered/filtered-parquet"
# test folder for destination parquet files 
#destination_parquet_folder ="G:/My Drive/Backtesting/FirstRateData/Stocks/filtered/test-filtered-parquet"

source_parquet_folder = "C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/"
# read in symbols that did not meet criteria so I can exclude them from the parquet files
df_excluded_tickers = pd.read_csv(stats_folder + "num_zero_days_tickers.csv")
#print(df_excluded_tickers)
excluded_tickers = df_excluded_tickers['Symbol'].to_list()
#print(excluded_tickers)

tickers_included_count = 0
tickers_excluded_count = 0
for filename in os.listdir(source_filtered_csv_folder):

    try:
        filename_str = str(filename)
        ticker = filename_str.split('_')[0]
        #print(ticker)
        if ticker in excluded_tickers:
            tickers_excluded_count += 1
            continue
        market_cap_url = f'https://api.polygon.io/v3/reference/tickers/{ticker}?apiKey={API_key}'
        
    
    
        response_cap = requests.get(market_cap_url)
        #print(response_bars)
        #print(response_bars.json())
        if response_cap.status_code != 200:
            #print(f'Error: {response_cap.status_code}')
            #print(f'Error message: {response_cap.json()}')
            tickers_excluded_count += 1
            continue
            
        if 'results' not in response_cap.json() or len(response_cap.json()['results']) == 0:
            #print('No results for marketcap api', ticker)
            tickers_excluded_count += 1
            continue
            
        market_cap  = response_cap.json()['results']['market_cap']
        print (ticker, market_cap)
        if market_cap < market_cap_threshold:
            print(f'Market cap too low: {ticker}')
            tickers_excluded_count += 1
            continue



        try:
             df = pd.read_csv(source_filtered_csv_folder  + filename_str)
        except pd.errors.ParserError as e:
            print(f"Parser error encountered while reading {filename_str}: {e}")
            continue

        df_all_conditions = df[df['all_conditions'] == True].copy()
        # Convert 'Datetime' to datetime objects, coercing errors
        df_all_conditions['Datetime'] = pd.to_datetime(df_all_conditions['Datetime'], format='mixed', errors='coerce')

        # Identify rows with invalid or missing dates
        invalid_dates = df_all_conditions[df_all_conditions['Datetime'].isna()]
        if not invalid_dates.empty:
            print("Rows with bad, missing, or incorrectly formatted dates:")
            print(invalid_dates)
        #print('length invalid_dates', len(invalid_dates))
        # Drop rows with NaT (invalid dates)
        df_all_conditions = df_all_conditions.dropna(subset=['Datetime'])

        # Extract unique dates and format them
        list_of_dates = df_all_conditions['Datetime'].dt.strftime('%Y-%m-%d').tolist()

        # check if there are any misformatted dates
        
        
        #print(type(list_of_dates))
       
        #print(list_of_dates)
        
        ticker_parquet_folder_source = ticker + "_1min_parquet/"
        destination_sub_folder = os.path.join(destination_parquet_folder, f'{ticker}_1min_parquet')
        destination_sub_folder = os.path.normpath(destination_sub_folder)
        destination_sub_folder = destination_sub_folder.replace(os.sep, '/')

        #print('destination_sub_folder', destination_sub_folder)
        
        if not os.path.exists(destination_sub_folder):
            os.makedirs(destination_sub_folder)
        tickers_included_count += 1
        for date_entry in list_of_dates:

            try:
                #print(date_entry)
                
                
                ticker_parquet_filename = date_entry + f"_{ticker}" + "_1min.parquet"
                source_file = os.path.join(source_parquet_folder, ticker_parquet_folder_source, ticker_parquet_filename)
                source_file = os.path.normpath(source_file)
                source_file = source_file.replace(os.sep, '/')
                #print('source_file', source_file)
                destination_file = os.path.join(destination_sub_folder,  ticker_parquet_filename)
                destination_file = destination_file.replace(os.sep, '/')    
                #print('destination_file', destination_file)
                shutil.copy(source_file, destination_file)
            except Exception as e:
                print("error with date " + ticker, date_entry)
                tb = traceback.format_exc()
                print(f'An error occurred in date loop: {str(e)}')
                continue
                
            
            
        
    except Exception as e:
        
        print("error with " + ticker)
        
        print(f'An error occurred in ticker loop: {str(e)}')
        continue
print('tickers_included_count', tickers_included_count)
print('tickers_excluded_count', tickers_excluded_count)

end = dt.now()
print(start)
print(end)
print(end-start)
# Out:
# AMGN 145969244040.12
# error with date AMGN 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMGN_1min_parquet/2024-12-11_AMGN_1min.parquet'
# error with date AMGN 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMGN_1min_parquet/2024-12-12_AMGN_1min.parquet'
# error with date AMGN 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMGN_1min_parquet/2024-12-13_AMGN_1min.parquet'
# ALC 41729402000.0
# error with date ALC 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALC_1min_parquet/2024-12-11_ALC_1min.parquet'
# error with date ALC 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALC_1min_parquet/2024-12-12_ALC_1min.parquet'
# error with date ALC 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALC_1min_parquet/2024-12-13_ALC_1min.parquet'
# ALK 8421502044.06
# error with date ALK 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALK_1min_parquet/2024-12-11_ALK_1min.parquet'
# error with date ALK 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALK_1min_parquet/2024-12-12_ALK_1min.parquet'
# error with date ALK 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALK_1min_parquet/2024-12-13_ALK_1min.parquet'
# ALEC 167464754.54999998
# AMPG 39902613.8
# Market cap too low: AMPG
# AMLX 308486581.2
# error with date AMLX 2022-03-30
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMLX_1min_parquet/2022-03-30_AMLX_1min.parquet'
# ACAD 2923505524.87
# error with date ACAD 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACAD_1min_parquet/2024-12-11_ACAD_1min.parquet'
# error with date ACAD 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACAD_1min_parquet/2024-12-12_ACAD_1min.parquet'
# error with date ACAD 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACAD_1min_parquet/2024-12-13_ACAD_1min.parquet'
# ANET 151108155863.4
# error with date ANET 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ANET_1min_parquet/2024-12-11_ANET_1min.parquet'
# error with date ANET 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ANET_1min_parquet/2024-12-12_ANET_1min.parquet'
# error with date ANET 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ANET_1min_parquet/2024-12-13_ANET_1min.parquet'
# AMD 197106180245.16
# error with date AMD 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMD_1min_parquet/2024-12-11_AMD_1min.parquet'
# error with date AMD 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMD_1min_parquet/2024-12-12_AMD_1min.parquet'
# error with date AMD 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMD_1min_parquet/2024-12-13_AMD_1min.parquet'
# ANDE 1512708133.2
# AMC 1335146935.5
# ANF 6566080011.15
# error with date ANF 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ANF_1min_parquet/2024-12-11_ANF_1min.parquet'
# error with date ANF 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ANF_1min_parquet/2024-12-12_ANF_1min.parquet'
# error with date ANF 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ANF_1min_parquet/2024-12-13_ANF_1min.parquet'
# ALVO 4000660778.92
# AEI 8809238.6514
# Market cap too low: AEI
# ALVR 46628761.279999994
# Market cap too low: ALVR
# AMPX 371530666.08
# ALXO 91773000.96
# AKRO 1754750580.72
# error with date AKRO 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AKRO_1min_parquet/2024-12-11_AKRO_1min.parquet'
# ALEX 1274708219.8500001
# ALTO 141796988.85
# AHCO 1415517432.28
# AGYS 3404651623.1
# AG 1761385207.04
# AHH 777810892.64
# AMG 5652099684.0
# ALRM 3079579613.7599998
# AMPH 1716507158.1000001
# AEVA 239778464.45000002
# AMPS 609598197.87
# AMRC 1208805410.55
# AMPL 1391750967.5
# ALSN 10352293815.75
# error with date ALSN 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALSN_1min_parquet/2024-12-12_ALSN_1min.parquet'
# error with date ALSN 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALSN_1min_parquet/2024-12-13_ALSN_1min.parquet'
# ALKT 3569641150.0800004
# error with date ALKT 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALKT_1min_parquet/2024-12-11_ALKT_1min.parquet'
# error with date ALKT 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALKT_1min_parquet/2024-12-12_ALKT_1min.parquet'
# error with date ALKT 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALKT_1min_parquet/2024-12-13_ALKT_1min.parquet'
# ANRO 125141579.52
# AEMD 9267974.2724
# Market cap too low: AEMD
# AMP 53570473199.54001
# ALHC 2794929035.94
# error with date ALHC 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALHC_1min_parquet/2024-12-11_ALHC_1min.parquet'
# error with date ALHC 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALHC_1min_parquet/2024-12-12_ALHC_1min.parquet'
# error with date ALHC 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALHC_1min_parquet/2024-12-13_ALHC_1min.parquet'
# ALGS 122849422.08000001
# AMED 3010462694.33
# error with date AMED 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMED_1min_parquet/2024-12-11_AMED_1min.parquet'
# error with date AMED 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMED_1min_parquet/2024-12-12_AMED_1min.parquet'
# error with date AMED 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMED_1min_parquet/2024-12-13_AMED_1min.parquet'
# ALGT 1877742929.1599998
# AEM 42643996632.16
# error with date AEM 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEM_1min_parquet/2024-12-11_AEM_1min.parquet'
# error with date AEM 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEM_1min_parquet/2024-12-12_AEM_1min.parquet'
# error with date AEM 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEM_1min_parquet/2024-12-13_AEM_1min.parquet'
# ALTR 9417460035.14
# error with date ALTR 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALTR_1min_parquet/2024-12-11_ALTR_1min.parquet'
# error with date ALTR 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALTR_1min_parquet/2024-12-12_ALTR_1min.parquet'
# error with date ALTR 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALTR_1min_parquet/2024-12-13_ALTR_1min.parquet'
# ALTS 83713340.55
# AMBA 3369100782.8700004
# error with date AMBA 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMBA_1min_parquet/2024-12-11_AMBA_1min.parquet'
# error with date AMBA 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMBA_1min_parquet/2024-12-12_AMBA_1min.parquet'
# error with date AMBA 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMBA_1min_parquet/2024-12-13_AMBA_1min.parquet'
# ALNY 31764130429.59
# error with date ALNY 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALNY_1min_parquet/2024-12-11_ALNY_1min.parquet'
# error with date ALNY 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALNY_1min_parquet/2024-12-12_ALNY_1min.parquet'
# error with date ALNY 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALNY_1min_parquet/2024-12-13_ALNY_1min.parquet'
# ADNT 1454616317.82
# error with date ADNT 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADNT_1min_parquet/2024-12-11_ADNT_1min.parquet'
# error with date ADNT 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADNT_1min_parquet/2024-12-12_ADNT_1min.parquet'
# error with date ADNT 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADNT_1min_parquet/2024-12-13_ADNT_1min.parquet'
# ADPT 1005016299.66
# ACLS 2327762608.71
# AFYA 1423650449.68
# AGL 1273135141.05
# error with ADXS
# An error occurred in ticker loop: 'market_cap'
# AGCO 7590678624.889999
# error with date AGCO 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AGCO_1min_parquet/2024-12-11_AGCO_1min.parquet'
# error with date AGCO 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AGCO_1min_parquet/2024-12-12_AGCO_1min.parquet'
# error with date AGCO 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AGCO_1min_parquet/2024-12-13_AGCO_1min.parquet'
# AFG 11337922520.949999
# AFMD 18851194.45
# Market cap too low: AFMD
# AFL 59158221126.329994
# error with date AFL 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AFL_1min_parquet/2024-12-11_AFL_1min.parquet'
# error with date AFL 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AFL_1min_parquet/2024-12-12_AFL_1min.parquet'
# error with date AFL 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AFL_1min_parquet/2024-12-13_AFL_1min.parquet'
# AGO 4828261753.400001
# error with AGNCP
# An error occurred in ticker loop: 'market_cap'
# ADT 6477667374.379999
# ADVM 90074664.79
# ADV 808299447.48
# AGM 2129480782.8600001
# AESI 2667247431.2
# error with date AESI 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AESI_1min_parquet/2024-12-11_AESI_1min.parquet'
# error with date AESI 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AESI_1min_parquet/2024-12-12_AESI_1min.parquet'
# error with date AESI 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AESI_1min_parquet/2024-12-13_AESI_1min.parquet'
# AEG 10372763127.09
# AEO 3079391581.4900002
# error with date AEO 2006-12-05
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEO_1min_parquet/2006-12-05_AEO_1min.parquet'
# error with date AEO 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEO_1min_parquet/2024-12-11_AEO_1min.parquet'
# error with date AEO 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEO_1min_parquet/2024-12-12_AEO_1min.parquet'
# error with date AEO 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEO_1min_parquet/2024-12-13_AEO_1min.parquet'
# ADM 24523904616.12
# error with date ADM 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADM_1min_parquet/2024-12-11_ADM_1min.parquet'
# error with date ADM 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADM_1min_parquet/2024-12-12_ADM_1min.parquet'
# error with date ADM 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADM_1min_parquet/2024-12-13_ADM_1min.parquet'
# ADMA 3786971853.06
# error with date ADMA 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADMA_1min_parquet/2024-12-11_ADMA_1min.parquet'
# error with date ADMA 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADMA_1min_parquet/2024-12-12_ADMA_1min.parquet'
# error with date ADMA 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADMA_1min_parquet/2024-12-13_ADMA_1min.parquet'
# ADI 108768418522.64
# error with date ADI 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADI_1min_parquet/2024-12-11_ADI_1min.parquet'
# error with date ADI 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADI_1min_parquet/2024-12-12_ADI_1min.parquet'
# error with date ADI 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADI_1min_parquet/2024-12-13_ADI_1min.parquet'
# ADN 18350095.68
# Market cap too low: ADN
# ACHC 4066520710.56
# error with date ACHC 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACHC_1min_parquet/2024-12-11_ACHC_1min.parquet'
# error with date ACHC 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACHC_1min_parquet/2024-12-12_ACHC_1min.parquet'
# error with date ACHC 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACHC_1min_parquet/2024-12-13_ACHC_1min.parquet'
# AEIS 4564468797.72
# AEP 51791978828.75
# error with date AEP 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEP_1min_parquet/2024-12-11_AEP_1min.parquet'
# error with date AEP 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEP_1min_parquet/2024-12-12_AEP_1min.parquet'
# error with date AEP 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEP_1min_parquet/2024-12-13_AEP_1min.parquet'
# AES 8404339648.26
# ADXN 8519531.5
# Market cap too low: ADXN
# AEE 25124556000.0
# error with date AEE 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEE_1min_parquet/2024-12-11_AEE_1min.parquet'
# error with date AEE 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEE_1min_parquet/2024-12-12_AEE_1min.parquet'
# error with date AEE 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEE_1min_parquet/2024-12-13_AEE_1min.parquet'
# AFRM 18007606110.93
# error with date AFRM 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AFRM_1min_parquet/2024-12-11_AFRM_1min.parquet'
# error with date AFRM 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AFRM_1min_parquet/2024-12-12_AFRM_1min.parquet'
# error with date AFRM 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AFRM_1min_parquet/2024-12-13_AFRM_1min.parquet'
# AAP 2742411491.83
# error with date AAP 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AAP_1min_parquet/2024-12-11_AAP_1min.parquet'
# error with date AAP 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AAP_1min_parquet/2024-12-12_AAP_1min.parquet'
# error with date AAP 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AAP_1min_parquet/2024-12-13_AAP_1min.parquet'
# AAL 11986770584.88
# error with date AAL 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AAL_1min_parquet/2024-12-11_AAL_1min.parquet'
# error with date AAL 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AAL_1min_parquet/2024-12-12_AAL_1min.parquet'
# error with date AAL 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AAL_1min_parquet/2024-12-13_AAL_1min.parquet'
# ACN 220537970986.83
# error with date ACN 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACN_1min_parquet/2024-12-11_ACN_1min.parquet'
# error with date ACN 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACN_1min_parquet/2024-12-12_ACN_1min.parquet'
# error with date ACN 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACN_1min_parquet/2024-12-13_ACN_1min.parquet'
# ACRS 275038148.95
# ACRE 323225389.22999996
# ADSK 62809956405.299995
# error with date ADSK 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADSK_1min_parquet/2024-12-11_ADSK_1min.parquet'
# error with date ADSK 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADSK_1min_parquet/2024-12-12_ADSK_1min.parquet'
# error with date ADSK 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADSK_1min_parquet/2024-12-13_ADSK_1min.parquet'
# ADTX 1871798.615
# Market cap too low: ADTX
# ADTN 808127314.61
# AEHR 370209077.84000003
# error with date AEHR 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEHR_1min_parquet/2024-12-11_AEHR_1min.parquet'
# error with date AEHR 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEHR_1min_parquet/2024-12-12_AEHR_1min.parquet'
# error with date AEHR 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AEHR_1min_parquet/2024-12-13_AEHR_1min.parquet'
# AMRN 229526677.09800002
# ALDX 288220054.32
# ALLO 381603205.62
# AER 18981407874.0
# error with date AER 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AER_1min_parquet/2024-12-11_AER_1min.parquet'
# error with date AER 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AER_1min_parquet/2024-12-12_AER_1min.parquet'
# error with date AER 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AER_1min_parquet/2024-12-13_AER_1min.parquet'
# ACI 11379009982.28
# error with date ACI 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACI_1min_parquet/2024-12-11_ACI_1min.parquet'
# error with date ACI 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACI_1min_parquet/2024-12-12_ACI_1min.parquet'
# error with date ACI 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACI_1min_parquet/2024-12-13_ACI_1min.parquet'
# AMIX 5550417.86
# Market cap too low: AMIX
# AMKR 6390210764.6
# error with date AMKR 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMKR_1min_parquet/2024-12-11_AMKR_1min.parquet'
# error with date AMKR 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMKR_1min_parquet/2024-12-12_AMKR_1min.parquet'
# error with date AMKR 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMKR_1min_parquet/2024-12-13_AMKR_1min.parquet'
# AIZ 10999676268.36
# ADX 2337878987.34
# AAOI 1532659173.5700002
# error with date AAOI 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AAOI_1min_parquet/2024-12-11_AAOI_1min.parquet'
# error with date AAOI 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AAOI_1min_parquet/2024-12-12_AAOI_1min.parquet'
# error with date AAOI 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AAOI_1min_parquet/2024-12-13_AAOI_1min.parquet'
# AAON 10702004200.58
# ACHV 106264933.14
# ACIC 584244139.4399999
# ACIU 265167593.76000002
# ACIW 5647204485.280001
# error with date ACIW 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACIW_1min_parquet/2024-12-11_ACIW_1min.parquet'
# error with date ACIW 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACIW_1min_parquet/2024-12-12_ACIW_1min.parquet'
# error with date ACIW 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACIW_1min_parquet/2024-12-13_ACIW_1min.parquet'
# ACTG 427446244.34999996
# ADC 7865729121.88
# error with date ADC 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADC_1min_parquet/2024-12-11_ADC_1min.parquet'
# error with date ADC 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADC_1min_parquet/2024-12-12_ADC_1min.parquet'
# error with date ADC 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADC_1min_parquet/2024-12-13_ADC_1min.parquet'
# ADBE 187178578398.57
# error with date ADBE 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADBE_1min_parquet/2024-12-11_ADBE_1min.parquet'
# error with date ADBE 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADBE_1min_parquet/2024-12-12_ADBE_1min.parquet'
# error with date ADBE 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADBE_1min_parquet/2024-12-13_ADBE_1min.parquet'
# ACGL 35863454575.87
# error with date ACGL 2002-04-19
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACGL_1min_parquet/2002-04-19_ACGL_1min.parquet'
# error with date ACGL 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACGL_1min_parquet/2024-12-11_ACGL_1min.parquet'
# error with date ACGL 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACGL_1min_parquet/2024-12-12_ACGL_1min.parquet'
# error with date ACGL 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACGL_1min_parquet/2024-12-13_ACGL_1min.parquet'
# ADP 120680584938.18001
# error with date ADP 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADP_1min_parquet/2024-12-11_ADP_1min.parquet'
# error with date ADP 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADP_1min_parquet/2024-12-12_ADP_1min.parquet'
# error with date ADP 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ADP_1min_parquet/2024-12-13_ADP_1min.parquet'
# ACCO 482981241.6
# error with date ACCO 2007-06-01
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACCO_1min_parquet/2007-06-01_ACCO_1min.parquet'
# ACET 74853032.064
# ACEL 919705859.0400001
# ACDC 1426906223.82
# ACCD 562767076.6899999
# ACHR 4424474149.2
# error with AAXJ
# An error occurred in ticker loop: 'market_cap'
# AA 10212766350.84
# error with date AA 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AA_1min_parquet/2024-12-11_AA_1min.parquet'
# error with date AA 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AA_1min_parquet/2024-12-12_AA_1min.parquet'
# error with date AA 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AA_1min_parquet/2024-12-13_AA_1min.parquet'
# AAT 1510968274.23
# ADEA 1411702986.04
# ADCT 176941999.11
# ACM 14429271276.720001
# error with date ACM 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACM_1min_parquet/2024-12-11_ACM_1min.parquet'
# error with date ACM 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACM_1min_parquet/2024-12-12_ACM_1min.parquet'
# error with date ACM 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACM_1min_parquet/2024-12-13_ACM_1min.parquet'
# ACNT 111930992.94
# ACLX 3594884061.6000004
# ALLE 11612882648.79
# error with date ALLE 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALLE_1min_parquet/2024-12-11_ALLE_1min.parquet'
# error with date ALLE 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALLE_1min_parquet/2024-12-12_ALLE_1min.parquet'
# error with date ALLE 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALLE_1min_parquet/2024-12-13_ALLE_1min.parquet'
# ANNX 447692721.0
# AMZN 2375761587147.52
# error with date AMZN 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMZN_1min_parquet/2024-12-11_AMZN_1min.parquet'
# error with date AMZN 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMZN_1min_parquet/2024-12-12_AMZN_1min.parquet'
# error with date AMZN 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMZN_1min_parquet/2024-12-13_AMZN_1min.parquet'
# error with ACWX
# An error occurred in ticker loop: 'market_cap'
# ACT 4996258757.92
# ACRV 179967790.88
# ABM 3302376966.3900003
# AAPL 3458410262520.0
# error with date AAPL 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AAPL_1min_parquet/2024-12-11_AAPL_1min.parquet'
# error with date AAPL 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AAPL_1min_parquet/2024-12-12_AAPL_1min.parquet'
# error with date AAPL 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AAPL_1min_parquet/2024-12-13_AAPL_1min.parquet'
# AL 5196379880.62
# error with date AL 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AL_1min_parquet/2024-12-11_AL_1min.parquet'
# error with date AL 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AL_1min_parquet/2024-12-12_AL_1min.parquet'
# error with date AL 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AL_1min_parquet/2024-12-13_AL_1min.parquet'
# AMAT 159573837219.80002
# error with date AMAT 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMAT_1min_parquet/2024-12-11_AMAT_1min.parquet'
# error with date AMAT 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMAT_1min_parquet/2024-12-12_AMAT_1min.parquet'
# error with date AMAT 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMAT_1min_parquet/2024-12-13_AMAT_1min.parquet'
# AGX 2414877385.24
# ACMR 1104755221.08
# error with date ACMR 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACMR_1min_parquet/2024-12-11_ACMR_1min.parquet'
# error with date ACMR 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACMR_1min_parquet/2024-12-12_ACMR_1min.parquet'
# error with date ACMR 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACMR_1min_parquet/2024-12-13_ACMR_1min.parquet'
# ADAP 148386671.73929998
# ADD 1020295.7599999999
# Market cap too low: ADD
# AISP 138332491.05
# ALKS 4986952035.17
# error with date ALKS 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALKS_1min_parquet/2024-12-11_ALKS_1min.parquet'
# error with date ALKS 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALKS_1min_parquet/2024-12-12_ALKS_1min.parquet'
# error with date ALKS 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALKS_1min_parquet/2024-12-13_ALKS_1min.parquet'
# AIRE 74607774.84
# AKR 2337060250.2
# AMRX 2559314991.7999997
# ACVA 3609288403.3900003
# error with date ACVA 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACVA_1min_parquet/2024-12-11_ACVA_1min.parquet'
# error with date ACVA 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACVA_1min_parquet/2024-12-12_ACVA_1min.parquet'
# error with date ACVA 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ACVA_1min_parquet/2024-12-13_ACVA_1min.parquet'
# ABG 4794618214.02
# ABCB 4477596105.9
# ABCL 877237851.6
# ABEO 226918776.6
# AM 7937032759.999999
# ALLT 295848632.31
# AMX 41672311500.0
# error with date AMX 2007-06-01
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/AMX_1min_parquet/2007-06-01_AMX_1min.parquet'
# ALV 7727121317.52
# error with date ALV 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALV_1min_parquet/2024-12-11_ALV_1min.parquet'
# error with date ALV 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALV_1min_parquet/2024-12-12_ALV_1min.parquet'
# error with date ALV 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALV_1min_parquet/2024-12-13_ALV_1min.parquet'
# ANIP 1225418000.54
# AMTX 141246184.48
# AKBA 451635088.14
# AIRG 85084792.5
# ALLY 11253116973.12
# error with date ALLY 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALLY_1min_parquet/2024-12-11_ALLY_1min.parquet'
# error with date ALLY 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALLY_1min_parquet/2024-12-12_ALLY_1min.parquet'
# error with date ALLY 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALLY_1min_parquet/2024-12-13_ALLY_1min.parquet'
# ANGH 46805287.199999996
# Market cap too low: ANGH
# ANGO 502988762.87
# ABBV 303170593813.88
# error with date ABBV 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ABBV_1min_parquet/2024-12-11_ABBV_1min.parquet'
# error with date ABBV 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ABBV_1min_parquet/2024-12-12_ABBV_1min.parquet'
# error with date ABBV 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ABBV_1min_parquet/2024-12-13_ABBV_1min.parquet'
# ALL 50021373405.1
# error with date ALL 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALL_1min_parquet/2024-12-11_ALL_1min.parquet'
# error with date ALL 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALL_1min_parquet/2024-12-12_ALL_1min.parquet'
# error with date ALL 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALL_1min_parquet/2024-12-13_ALL_1min.parquet'
# ALIT 3615718041.81
# ALGN 16739455643.8
# error with date ALGN 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALGN_1min_parquet/2024-12-11_ALGN_1min.parquet'
# error with date ALGN 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALGN_1min_parquet/2024-12-12_ALGN_1min.parquet'
# error with date ALGN 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ALGN_1min_parquet/2024-12-13_ALGN_1min.parquet'
# error with AIA
# An error occurred in ticker loop: 'market_cap'
# ANAB 482294609.7
# error with date ANAB 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ANAB_1min_parquet/2024-12-11_ANAB_1min.parquet'
# error with date ANAB 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ANAB_1min_parquet/2024-12-12_ANAB_1min.parquet'
# error with date ANAB 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ANAB_1min_parquet/2024-12-13_ANAB_1min.parquet'
# ALTG 242438580.09
# AADI 73548509.84
# ALT 487914927.5
# AMR 2507534326.5
# AMRK 632461129.52
# ACB 211277066.0
# ASND 7663167904.41
# ARWR 2429356498.7999997
# error with date ARWR 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ARWR_1min_parquet/2024-12-11_ARWR_1min.parquet'
# error with date ARWR 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ARWR_1min_parquet/2024-12-12_ARWR_1min.parquet'
# error with date ARWR 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ARWR_1min_parquet/2024-12-13_ARWR_1min.parquet'
# ASUR 321199573.7
# ATGL 275746875.0
# ATAT 3556836850.6000004
# error with date ATAT 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ATAT_1min_parquet/2024-12-11_ATAT_1min.parquet'
# error with date ATAT 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ATAT_1min_parquet/2024-12-12_ATAT_1min.parquet'
# error with date ATAT 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ATAT_1min_parquet/2024-12-13_ATAT_1min.parquet'
# ARL 254879238.54
# ATKR 2957418636.21
# error with date ATKR 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ATKR_1min_parquet/2024-12-11_ATKR_1min.parquet'
# error with date ATKR 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ATKR_1min_parquet/2024-12-12_ATKR_1min.parquet'
# error with date ATKR 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ATKR_1min_parquet/2024-12-13_ATKR_1min.parquet'
# error with ATLC
# An error occurred in ticker loop: 'market_cap'
# ATRA 37841557.5
# Market cap too low: ATRA
# ASH 3370097972.0400004
# ASPS 17800380.375400003
# Market cap too low: ASPS
# ATAI 244991498.16
# ASO 3648899360.2599998
# error with date ASO 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASO_1min_parquet/2024-12-11_ASO_1min.parquet'
# error with date ASO 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASO_1min_parquet/2024-12-12_ASO_1min.parquet'
# error with date ASO 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASO_1min_parquet/2024-12-13_ASO_1min.parquet'
# ASTH 1605650511.77
# ARMK 10372817888.4
# error with date ARMK 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ARMK_1min_parquet/2024-12-11_ARMK_1min.parquet'
# error with date ARMK 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ARMK_1min_parquet/2024-12-12_ARMK_1min.parquet'
# error with date ARMK 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ARMK_1min_parquet/2024-12-13_ARMK_1min.parquet'
# error with AUMN
# An error occurred in ticker loop: 'market_cap'
# ARCT 454796757.60999995
# ATNM 43674247.4
# Market cap too low: ATNM
# ASML 297389042977.95
# error with date ASML 2007-10-01
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-01_ASML_1min.parquet'
# error with date ASML 2007-10-02
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-02_ASML_1min.parquet'
# error with date ASML 2007-10-03
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-03_ASML_1min.parquet'
# error with date ASML 2007-10-04
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-04_ASML_1min.parquet'
# error with date ASML 2007-10-05
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-05_ASML_1min.parquet'
# error with date ASML 2007-10-08
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-08_ASML_1min.parquet'
# error with date ASML 2007-10-09
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-09_ASML_1min.parquet'
# error with date ASML 2007-10-10
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-10_ASML_1min.parquet'
# error with date ASML 2007-10-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-11_ASML_1min.parquet'
# error with date ASML 2007-10-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-12_ASML_1min.parquet'
# error with date ASML 2007-10-15
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-15_ASML_1min.parquet'
# error with date ASML 2007-10-16
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-16_ASML_1min.parquet'
# error with date ASML 2007-10-17
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-17_ASML_1min.parquet'
# error with date ASML 2007-10-18
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-18_ASML_1min.parquet'
# error with date ASML 2007-10-19
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-19_ASML_1min.parquet'
# error with date ASML 2007-10-22
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-22_ASML_1min.parquet'
# error with date ASML 2007-10-23
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-23_ASML_1min.parquet'
# error with date ASML 2007-10-24
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ASML_1min_parquet/2007-10-24_ASML_1min.parquet'
# error with date ASML 2007-10-25
# ...
# error with date TXRH 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/TXRH_1min_parquet/2024-12-11_TXRH_1min.parquet'
# error with date TXRH 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/TXRH_1min_parquet/2024-12-12_TXRH_1min.parquet'
# error with date TXRH 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/TXRH_1min_parquet/2024-12-13_TXRH_1min.parquet'
# UTHR 16575617014.32
# UNP 143866796367.6
# error with date UNP 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/UNP_1min_parquet/2024-12-11_UNP_1min.parquet'
# error with date UNP 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/UNP_1min_parquet/2024-12-12_UNP_1min.parquet'
# error with date UNP 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/UNP_1min_parquet/2024-12-13_UNP_1min.parquet'
# USM 5457072895.650001
# TSLA 1332527865047.49
# error with date TSLA 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/TSLA_1min_parquet/2024-12-11_TSLA_1min.parquet'
# error with date TSLA 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/TSLA_1min_parquet/2024-12-12_TSLA_1min.parquet'
# error with date TSLA 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/TSLA_1min_parquet/2024-12-13_TSLA_1min.parquet'
# UNM 13757980395.32
# error with date UNM 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/UNM_1min_parquet/2024-12-11_UNM_1min.parquet'
# error with date UNM 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/UNM_1min_parquet/2024-12-12_UNM_1min.parquet'
# error with date UNM 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/UNM_1min_parquet/2024-12-13_UNM_1min.parquet'
# VTSI 74484433.5
# TLK 16830670600.339998
# TPL 32525126251.52
# error with date TPL 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/TPL_1min_parquet/2024-12-11_TPL_1min.parquet'
# error with date TPL 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/TPL_1min_parquet/2024-12-12_TPL_1min.parquet'
# TPST 38531585.3688
# Market cap too low: TPST
# TNL 3633074754.24
# error with date TNL 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/TNL_1min_parquet/2024-12-11_TNL_1min.parquet'
# error with date TNL 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/TNL_1min_parquet/2024-12-12_TNL_1min.parquet'
# error with date TNL 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/TNL_1min_parquet/2024-12-13_TNL_1min.parquet'
# TOUR 118888327.15
# TRS 999922694.4000001
# TREE 578709692.5400001
# TRUE 313568557.65000004
# TRV 56010118551.36
# error with date TRV 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/TRV_1min_parquet/2024-12-11_TRV_1min.parquet'
# error with date TRV 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/TRV_1min_parquet/2024-12-12_TRV_1min.parquet'
# error with date TRV 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/TRV_1min_parquet/2024-12-13_TRV_1min.parquet'
# UTI 1442317484.3700001
# error with date UTI 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/UTI_1min_parquet/2024-12-11_UTI_1min.parquet'
# error with date UTI 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/UTI_1min_parquet/2024-12-12_UTI_1min.parquet'
# error with date UTI 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/UTI_1min_parquet/2024-12-13_UTI_1min.parquet'
# YOU 2335300438.18
# error with date YOU 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/YOU_1min_parquet/2024-12-11_YOU_1min.parquet'
# error with date YOU 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/YOU_1min_parquet/2024-12-12_YOU_1min.parquet'
# error with date YOU 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/YOU_1min_parquet/2024-12-13_YOU_1min.parquet'
# error with ZETA
# An error occurred in ticker loop: HTTPSConnectionPool(host='api.polygon.io', port=443): Max retries exceeded with url: /v3/reference/tickers/ZETA?apiKey=8bpVgiG0yENneJo_t7tm885PuZYZDw4X (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000027344CD1AF0>, 'Connection to api.polygon.io timed out. (connect timeout=None)'))
# ZH 299847649.0
# YY 2377069607.04
# ZJK 557341740.92
# error with date ZJK 2024-12-03
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZJK_1min_parquet/2024-12-03_ZJK_1min.parquet'
# error with date ZJK 2024-12-04
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZJK_1min_parquet/2024-12-04_ZJK_1min.parquet'
# error with date ZJK 2024-12-05
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZJK_1min_parquet/2024-12-05_ZJK_1min.parquet'
# error with date ZJK 2024-12-06
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZJK_1min_parquet/2024-12-06_ZJK_1min.parquet'
# error with date ZJK 2024-12-09
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZJK_1min_parquet/2024-12-09_ZJK_1min.parquet'
# error with date ZJK 2024-12-10
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZJK_1min_parquet/2024-12-10_ZJK_1min.parquet'
# error with date ZJK 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZJK_1min_parquet/2024-12-11_ZJK_1min.parquet'
# error with date ZJK 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZJK_1min_parquet/2024-12-12_ZJK_1min.parquet'
# error with date ZJK 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZJK_1min_parquet/2024-12-13_ZJK_1min.parquet'
# YALA 622765108.0
# WFC 255024704500.66003
# error with date WFC 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/WFC_1min_parquet/2024-12-11_WFC_1min.parquet'
# error with date WFC 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/WFC_1min_parquet/2024-12-12_WFC_1min.parquet'
# error with date WFC 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/WFC_1min_parquet/2024-12-13_WFC_1min.parquet'
# ZIMV 390524024.65000004
# XYF 376451669.06
# XYL 29551793672.920002
# error with date XYL 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/XYL_1min_parquet/2024-12-11_XYL_1min.parquet'
# error with date XYL 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/XYL_1min_parquet/2024-12-12_XYL_1min.parquet'
# error with date XYL 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/XYL_1min_parquet/2024-12-13_XYL_1min.parquet'
# YUM 35224449411.88
# error with date YUM 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/YUM_1min_parquet/2024-12-11_YUM_1min.parquet'
# error with date YUM 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/YUM_1min_parquet/2024-12-12_YUM_1min.parquet'
# error with date YUM 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/YUM_1min_parquet/2024-12-13_YUM_1min.parquet'
# ZNTL 161059803.99999997
# ZYME 1010433306.42
# ZKIN 23275455.7375
# Market cap too low: ZKIN
# ZYXI 260496558.1
# ZI 3395916986.9500003
# ZIP 680004973.4399999
# ZK 6501572252.5
# error with date ZK 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZK_1min_parquet/2024-12-11_ZK_1min.parquet'
# error with date ZK 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZK_1min_parquet/2024-12-12_ZK_1min.parquet'
# error with date ZK 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZK_1min_parquet/2024-12-13_ZK_1min.parquet'
# ZGN 2155636730.66
# ZM 24298918129.68
# error with date ZM 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZM_1min_parquet/2024-12-11_ZM_1min.parquet'
# error with date ZM 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZM_1min_parquet/2024-12-12_ZM_1min.parquet'
# error with date ZM 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZM_1min_parquet/2024-12-13_ZM_1min.parquet'
# ZG 18101653642.16
# ZD 2290079604.12
# error with date ZD 2007-06-01
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZD_1min_parquet/2007-06-01_ZD_1min.parquet'
# error with date ZD 2008-07-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZD_1min_parquet/2008-07-11_ZD_1min.parquet'
# error with date ZD 2008-07-14
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZD_1min_parquet/2008-07-14_ZD_1min.parquet'
# error with date ZD 2008-07-16
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZD_1min_parquet/2008-07-16_ZD_1min.parquet'
# error with date ZD 2008-07-23
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZD_1min_parquet/2008-07-23_ZD_1min.parquet'
# ZWS 6600173259.88
# error with date ZWS 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZWS_1min_parquet/2024-12-11_ZWS_1min.parquet'
# error with date ZWS 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZWS_1min_parquet/2024-12-12_ZWS_1min.parquet'
# error with date ZWS 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/ZWS_1min_parquet/2024-12-13_ZWS_1min.parquet'
# YMAB 277244380.44
# WHLR 5428138.06
# Market cap too low: WHLR
# YPF 16920478282.140001
# error with date YPF 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/YPF_1min_parquet/2024-12-11_YPF_1min.parquet'
# error with date YPF 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/YPF_1min_parquet/2024-12-12_YPF_1min.parquet'
# error with date YPF 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/YPF_1min_parquet/2024-12-13_YPF_1min.parquet'
# Z 18830195798.48
# error with date Z 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/Z_1min_parquet/2024-12-11_Z_1min.parquet'
# error with date Z 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/Z_1min_parquet/2024-12-12_Z_1min.parquet'
# error with date Z 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/Z_1min_parquet/2024-12-13_Z_1min.parquet'
# YQ 14376170.55
# Market cap too low: YQ
# YGMZ 5804107.485
# Market cap too low: YGMZ
# YUMC 16932528739.699999
# error with date YUMC 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/YUMC_1min_parquet/2024-12-11_YUMC_1min.parquet'
# error with date YUMC 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/YUMC_1min_parquet/2024-12-12_YUMC_1min.parquet'
# error with date YUMC 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/YUMC_1min_parquet/2024-12-13_YUMC_1min.parquet'
# WERN 2313466066.29
# error with date WERN 2024-12-11
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/WERN_1min_parquet/2024-12-11_WERN_1min.parquet'
# error with date WERN 2024-12-12
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/WERN_1min_parquet/2024-12-12_WERN_1min.parquet'
# error with date WERN 2024-12-13
# An error occurred in date loop: [Errno 2] No such file or directory: 'C:/Users/dansk/OneDrive/Documents/source-stocks1min-parquet/WERN_1min_parquet/2024-12-13_WERN_1min.parquet'
# tickers_included_count 3146
# tickers_excluded_count 4257
# 2025-01-19 14:21:21.785560
# 2025-01-23 03:17:43.786805
# 3 days, 12:56:22.001245
